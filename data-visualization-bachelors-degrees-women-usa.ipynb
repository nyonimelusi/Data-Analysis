# %% [markdown]
# I would just like to analyze the data and find some insights.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/percent-bachelors-degrees-women-usa.csv

# %%
women_degrees = pd.read_csv("/kaggle/input/percent-bachelors-degrees-women-usa.csv")

# %%
women_degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %% [markdown]
# Let us describe the DataSet. The describe() function for the DataFrame generates descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution.
#
# * There are 42 rows from Year 1970 to Year 2011
# * Some of the highest rates for Women graduating are in "Art & Performance", "Education", "English", "Foreign Languages", and "Health Professions", and "Psychology"
# * Some of the lowest rates are in "Engineering", "Computer Science", "Physical Sciences", and "Agriculture"
# * "Biology", "Journalism", "Social Sciences & History", and "Math & Statistics" are right in the middle
#
# Did any of this surprise you? Given the news about STEM and lack of Women I for one was surprised at the mean of "Math & Statistics" being at 44.5%

# %%
women_degrees.describe()
# Out:
#               Year  Agriculture  Architecture  Art and Performance    Biology  \
# count    42.000000    42.000000     42.000000            42.000000  42.000000
# mean   1990.500000    33.848165     33.685540            61.100000  49.429864
# std      12.267844    12.552731      9.574057             1.305336  10.087725
# min    1970.000000     4.229798     11.921005            58.600000  29.088363
# 25%    1980.250000    30.840814     28.520709            60.200000  44.311821
# 50%    1990.500000    33.317552     35.994852            61.300000  50.971469
# 75%    2000.750000    45.663953     40.790605            62.000000  58.679194
# max    2011.000000    50.037182     44.499331            63.400000  62.169456
#
#         Business  Communications and Journalism  Computer Science  Education  \
# count  42.000000                      42.000000         42.000000  42.000000
# mean   40.653471                      56.216667         25.809524  76.356236
# ...

# %%
women_degrees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           42 non-null     int64
#  1   Agriculture                    42 non-null     float64
#  2   Architecture                   42 non-null     float64
#  3   Art and Performance            42 non-null     float64
#  4   Biology                        42 non-null     float64
#  5   Business                       42 non-null     float64
#  6   Communications and Journalism  42 non-null     float64
#  7   Computer Science               42 non-null     float64
#  8   Education                      42 non-null     float64
#  9   Engineering                    42 non-null     float64
#  10  English                        42 non-null     float64
#  11  Foreign Languages              42 non-null     float64
# ...

# %% [markdown]
# Let us generate line charts for four STEM degree and compare the rates of Men and Women graduating. We will use the matplotlib.pyplot to plot our data. What conclusion can you draw?
#
# * Engineering and Computer Science have large gender gaps
# * The Gap in Biology and Math & Statistics is quite small
# * In Biology Women are getting to be a majority
# * In Math & Statistics the rates are dropping after getting very close in 2000

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.plot(women_degrees["Year"], women_degrees["Biology"])
plt.show()

# %%
plt.plot(women_degrees["Year"], women_degrees["Biology"], label = "Women")
plt.plot(women_degrees["Year"], 100-women_degrees["Biology"], label = "Men")
plt.legend(loc = "upper right")
plt.title("Degree awarded to Women")
plt.xlabel("Years")
plt.ylabel("Percentage")
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(women_degrees["Year"], women_degrees["Biology"], label = "Women", c = "red")
ax.plot(women_degrees["Year"], 100-women_degrees["Biology"], label = "Men", c = "green")
plt.legend(loc = "upper right")
ax.set_title("Degree awarded to Women")
plt.xlabel("Years")
ax.set_ylabel("Percentage")
ax.tick_params(left = False, bottom = False)
plt.show()

# %%
maj_cats = ["Biology", "Computer Science", "Engineering", "Math and Statistics"]

# %%
fig = plt.figure(figsize = (12,12))

for i in range(4):
    ax = fig.add_subplot(2,2,i+1)
    ax.plot(women_degrees["Year"], women_degrees[maj_cats[i]], label = "Women", c = "red",)
    ax.plot(women_degrees["Year"], 100-women_degrees[maj_cats[i]], label = "Men", c = "green")
    ax.tick_params(left = False, bottom = False)
    ax.set_title(maj_cats[i])
    ax.set_xlim(1968,2013)
    ax.set_ylim(0,100)
    
    for value in ax.spines.values():
        value.set_visible(False)
plt.legend()
plt.show()

# %%
dark_blue = (0/255,0/255,139/255)
orange = (255/255,165/255,0/255)

# %%
fig = plt.figure(figsize = (12,12))

for i in range(4):
    ax = fig.add_subplot(2,2,i+1)
    ax.plot(women_degrees["Year"], women_degrees[maj_cats[i]], label = "Women", c = dark_blue,)
    ax.plot(women_degrees["Year"], 100-women_degrees[maj_cats[i]], label = "Men", c = orange)
    ax.tick_params(left = False, bottom = False)
    ax.set_title(maj_cats[i])
    ax.set_xlim(1968,2013)
    ax.set_ylim(0,100)
    
    for value in ax.spines.values():
        value.set_visible(False)
plt.legend()
plt.show()

# %% [markdown]
# I would like to compare the growth for every 5 years

# %%
import seaborn as sns

# %%
sns.barplot(x="Year",y="Agriculture",data = women_degrees)

# %%
group = women_degrees.groupby("Year").mean().reset_index()

# %%
def plotmatrix(start,end):
    fig, axs = plt.subplots(nrows = 2, ncols=2)
    i = 0
    cols = women_degrees.columns[start:end]
    fig.set_size_inches(14, 10)
    for indi in range(2):
        for indj in range(2):
                sns.barplot(x="Year",y=str(cols[i]),data = group,ax = axs[indi][indj],\
                            order = ['71-76', '76-81', '81-86', '86-91', '91-96','96-01','01-06','06-11'])
                i+=1
                #plt.xticks(rotation = 90)

# %%
plotmatrix(1,5)

# %% [markdown]
# So from the above fig, it's clear that
#
# 1. Growth is in increasing order in Agriculture Field and even in Architecture Field
# 1. In Art and Performance, the growth is almost stagnant.
# 1. It's interesting to see that growth for Biology is declining from 2001-06 to 2006-11.

# %%
plotmatrix(6,10)

# %% [markdown]
# It's clearly understood that, women growth in Compute Science is declining

# %%
plotmatrix(11,15)

# %% [markdown]
# I hope you enjoyed this Kernel. Here are a few forks to try
# * Instead of focusing on the STEM field can we look at "Education", "Health Profession", "Foreign Language", and "Psychology"?
# * How can we plot the describe() output nicely?

# %% [markdown]
# # Please Upvote this notebook if it has helped you in any ways! Thank you
